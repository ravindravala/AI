# %% [markdown]
# <a href="https://colab.research.google.com/github/ravindravala/AI/blob/main/customerChurn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "telecom_churn.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "barun2104/telecom-churn",
  file_path,
  # Provide any additional arguments like
  # sql_query or pandas_kwargs. See the
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# /tmp/ipykernel_152/2392765166.py:10: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'telecom-churn' dataset.
# First 5 records:    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# ...

# %%
df.head()
# Out:
#    Churn  AccountWeeks  ContractRenewal  DataPlan  DataUsage  CustServCalls  \
# 0      0           128                1         1        2.7              1
# 1      0           107                1         1        3.7              1
# 2      0           137                1         0        0.0              0
# 3      0            84                0         0        0.0              2
# 4      0            75                0         0        0.0              3
#
#    DayMins  DayCalls  MonthlyCharge  OverageFee  RoamMins
# 0    265.1       110           89.0        9.87      10.0
# 1    161.6       123           82.0        9.78      13.7
# 2    243.4       114           52.0        6.06      12.2
# 3    299.4        71           57.0        3.10       6.6
# 4    166.7       113           41.0        7.42      10.1

# %%
import pandas as pd

# %%
x = df.drop('Churn', axis=1)
y = df['Churn']

# %%
split = int(len(x) * 0.8)

# %%
train_x = x[:split]
train_y = y[:split]

# %%
test_x = x[split:]
test_y = y[split:]

# %%
print(train_x.shape)
print(test_x.shape)
# Out:
# (2666, 10)
# (667, 10)

# %%
from torch.utils.data import Dataset, DataLoader

# %%
class ChurnDataset(Dataset):

    def __init__(self, x, y):
        self.x = torch.tensor(x.values, dtype=torch.float32)
        self.y = torch.tensor(y.values, dtype=torch.float32).unsqueeze(1)

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
train_dataset = ChurnDataset(train_x, train_y)
test_dataset = ChurnDataset(test_x, test_y)

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True
)

test_loader = DataLoader(
    test_dataset,
    batch_size=32
)

# %%
import torch
import torch.nn as nn

# %%
model = nn.Sequential(
    nn.Linear(10, 64),
    nn.ReLU(),
    nn.Linear(64,1)
)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
loss_function = nn.BCEWithLogitsLoss()

# %%
for epoch in range(80):

    total_loss = 0

    for X_batch, y_batch in train_loader:

        outputs = model(X_batch)

        loss = loss_function(outputs, y_batch)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    avg_loss = total_loss / len(train_loader)

    print(f"Epoch {epoch} | Loss: {avg_loss:.4f}")
# Out:
# Epoch 0 | Loss: 1.1681
# Epoch 1 | Loss: 0.4139
# Epoch 2 | Loss: 0.4050
# Epoch 3 | Loss: 0.3997
# Epoch 4 | Loss: 0.3897
# Epoch 5 | Loss: 0.4006
# Epoch 6 | Loss: 0.3987
# Epoch 7 | Loss: 0.4067
# Epoch 8 | Loss: 0.3839
# Epoch 9 | Loss: 0.3882
# Epoch 10 | Loss: 0.3789
# Epoch 11 | Loss: 0.3705
# Epoch 12 | Loss: 0.3698
# Epoch 13 | Loss: 0.3918
# Epoch 14 | Loss: 0.3643
# Epoch 15 | Loss: 0.3586
# Epoch 16 | Loss: 0.3584
# Epoch 17 | Loss: 0.3485
# Epoch 18 | Loss: 0.3639
# Epoch 19 | Loss: 0.3434
# Epoch 20 | Loss: 0.3594
# Epoch 21 | Loss: 0.3527
# Epoch 22 | Loss: 0.3472
# Epoch 23 | Loss: 0.3477
# Epoch 24 | Loss: 0.3407
# Epoch 25 | Loss: 0.3394
# Epoch 26 | Loss: 0.3450
# Epoch 27 | Loss: 0.3537
# Epoch 28 | Loss: 0.3479
# Epoch 29 | Loss: 0.3469
# Epoch 30 | Loss: 0.3326
# Epoch 31 | Loss: 0.3565
# Epoch 32 | Loss: 0.3560
# Epoch 33 | Loss: 0.3228
# Epoch 34 | Loss: 0.3231
# Epoch 35 | Loss: 0.3304
# Epoch 36 | Loss: 0.3403
# Epoch 37 | Loss: 0.3393
# ...

# %%
correct = 0
total = 0

with torch.no_grad():

    for X_batch, y_batch in test_loader:

        outputs = model(X_batch)

        preds = torch.sigmoid(outputs)
        preds = (preds > 0.5).float()

        correct += (preds == y_batch).sum().item()
        total += y_batch.size(0)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8620689655172413
